# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %% [markdown]
# Load the MNIST Dataset

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Display Dataset Shapes

# %%
print("Training Data Shape:", x_train.shape)
print("Testing Data Shape:", x_test.shape)
# Out:
# Training Data Shape: (60000, 28, 28)
# Testing Data Shape: (10000, 28, 28)

# %% [markdown]
# Display a Sample Image

# %%
plt.imshow(x_train[0], cmap='gray')
plt.title("Sample Image")
plt.axis('off')
plt.show()

print("Label:", y_train[0])
# Out:
# Label: 5

# %% [markdown]
# Normalize the Images

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# Reshape the Images

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %% [markdown]
# Build the CNN Model

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Flatten(),

    Dense(128, activation='relu'),

    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Display Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Compile the Model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Train the Model

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 46s 30ms/step - accuracy: 0.9544 - loss: 0.1482 - val_accuracy: 0.9780 - val_loss: 0.0717
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 41s 27ms/step - accuracy: 0.9848 - loss: 0.0478 - val_accuracy: 0.9887 - val_loss: 0.0426
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 83s 28ms/step - accuracy: 0.9897 - loss: 0.0321 - val_accuracy: 0.9862 - val_loss: 0.0467
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 41s 27ms/step - accuracy: 0.9925 - loss: 0.0224 - val_accuracy: 0.9908 - val_loss: 0.0378
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - accuracy: 0.9937 - loss: 0.0181 - val_accuracy: 0.9887 - val_loss: 0.0449
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 82s 27ms/step - accuracy: 0.9958 - loss: 0.0127 - val_accuracy: 0.9903 - val_loss: 0.0415
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 29ms/step - accuracy: 0.9956 - loss: 0.0112 - val_accuracy: 0.9893 - val_loss: 0.0459
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 42s 28ms/step - accuracy: 0.9974 - loss: 0.0082 - val_accuracy: 0.9885 - val_loss: 0.0517
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 83s 29ms/step - accuracy: 0.9975 - loss: 0.0079 - val_accuracy: 0.9888 - val_loss: 0.0512
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 29ms/step - accuracy: 0.9976 - loss: 0.0069 - val_accuracy: 0.9901 - val_loss: 0.0502

# %% [markdown]
# Evaluate the Model

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9905 - loss: 0.0392
# Test Loss: 0.03922662511467934
# Test Accuracy: 0.9904999732971191

# %% [markdown]
# Predict a Digit

# %%
prediction = model.predict(x_test[:1])

print("Predicted Digit:", prediction.argmax())
print("Actual Digit:", y_test[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Predicted Digit: 7
# Actual Digit: 7

# %% [markdown]
# Display the Predicted Image

# %%
plt.imshow(x_test[0].reshape(28,28), cmap='gray')
plt.title("Predicted Digit: {}".format(prediction.argmax()))
plt.axis('off')
plt.show()

# %% [markdown]
# Plot Accuracy

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("CNN Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["Training", "Validation"])

plt.show()

# %% [markdown]
# Plot Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title("CNN Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(["Training", "Validation"])

plt.show()
